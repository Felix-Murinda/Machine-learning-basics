# %%
pwd
# Out:
# 'C:\\Users\\User'

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/User/Desktop/Udemy machine learning/5. ST Academy - ANN resource files/Customer.csv")

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
df.shape
# Out:
# (793, 9)

# %%
df.describe()
# Out:
#               Age   Postal Code
# count  793.000000    793.000000
# mean    44.467844  55229.717528
# std     15.526673  31679.223816
# min     18.000000   1841.000000
# 25%     31.000000  27217.000000
# 50%     45.000000  55901.000000
# 75%     58.000000  90004.000000
# max     70.000000  99207.000000

# %%
sns.jointplot(x='Postal Code', y='Age', data=df)

# %%
df.head()
# Out:
#   Customer ID    Customer Name    Segment  Age        Country  \
# 0    CG-12520      Claire Gute   Consumer   67  United States
# 1    DV-13045  Darrin Van Huff  Corporate   31  United States
# 2    SO-20335   Sean O'Donnell   Consumer   65  United States
# 3    BH-11710  Brosina Hoffman   Consumer   20  United States
# 4    AA-10480     Andrew Allen   Consumer   50  United States
#
#               City           State  Postal Code Region
# 0        Henderson        Kentucky        42420  South
# 1      Los Angeles      California        90036   West
# 2  Fort Lauderdale         Florida        33311  South
# 3      Los Angeles      California        90032   West
# 4          Concord  North Carolina        28027  South

# %%
sns.countplot(x='Segment', data=df)

# %%
sns.countplot(x='Region', data=df)

# %%
sns.countplot(x='State', data=df)

# %%
sns.countplot(x='Country', data=df)

# %%
sns.countplot(x='City', data=df)

# %% [markdown]
# 1. All values present
# 2. No outlier sen
# 3. Country is taking only one value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer ID    793 non-null    object
#  1   Customer Name  793 non-null    object
#  2   Segment        793 non-null    object
#  3   Age            793 non-null    int64
#  4   Country        793 non-null    object
#  5   City           793 non-null    object
#  6   State          793 non-null    object
#  7   Postal Code    793 non-null    int64
#  8   Region         793 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 55.9+ KB

# %%
np.percentile(df.Age,[99])[0]
# Out:
# 70.0

# %%
uv=np.percentile(df.Age,[99])[0]

# %%
df[(df.Age>uv)]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Customer Name, Segment, Age, Country, City, State, Postal Code, Region]
# Index: []

# %%
df.Age[(df.Age>3*uv)]=3*uv
# Out:
# <ipython-input-31-b42d23aa8698>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[(df.Age>3*uv)]=3*uv

# %%
df2=pd.read_csv("C:/Users/User/Desktop/Udemy machine learning/1. ST Academy - Crash course and Regression files/House_Price.csv", header=0)

# %%
df2.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %% [markdown]
# # Observations
# 1. Missing values in n_hos_beds
# 2. skewness and outliers in crime rate
# 3. outliers in n_hot rooms and Raifall
# 4. bus_ter has only one value (yes)

# %%
np.percentile(df2.n_hot_rooms,[99])[0]
# Out:
# 15.399519999999999

# %%
uv2=np.percentile(df2.n_hot_rooms,[99])[0]

# %%
df2[(df2.n_hot_rooms>uv2)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 2     34.7     0.02729       37.07    0.4690     7.185  61.1   5.03   4.86
# 166   50.0     2.01019       49.58    0.6050     7.929  96.2   2.11   1.91
# 204   50.0     0.02009       32.68    0.4161     8.034  31.9   5.41   4.80
# 267   50.0     0.57834       33.97    0.5750     8.297  67.0   2.60   2.13
# 369   50.0     5.66998       48.10    0.6310     6.683  96.8   1.55   1.28
# 423   13.4     7.05042       48.10    0.6140     6.103  85.1   2.08   1.80
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 2     5.01   4.97      22.2       4.03      NO       7.394       101.12
# 166   2.31   1.86      25.3       3.70     YES       8.300        15.40
# 204   5.28   4.99      25.3       2.88     YES       8.900        15.40
# 267   2.43   2.52      27.0       7.44     YES       8.000        15.40
# 369   1.65   0.94      19.8       3.73     YES       6.700        15.40
# ...

# %%
df2.n_hot_rooms[(df2.n_hot_rooms>3*uv2)]=3*uv2
# Out:
# <ipython-input-41-da782088cda2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.n_hot_rooms[(df2.n_hot_rooms>3*uv2)]=3*uv2

# %%
np.percentile(df2.rainfall,[1])[0]
# Out:
# 20.0

# %%
uv21=np.percentile(df2.rainfall,[1])[0]

# %%
df2[(df2.rainfall<uv21)]
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 213   28.1     0.14052       40.59     0.489     6.375  32.3   4.11   3.92
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 213   4.18   3.57      21.4       9.38     YES       7.562      10.2248
#
#     waterbody  rainfall bus_ter     parks
# 213      None         3     YES  0.044019

# %%
df2.rainfall[(df2.rainfall<uv21*0.3)]=uv21*0.3
# Out:
# <ipython-input-47-bf8cfeb05859>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rainfall[(df2.rainfall<uv21*0.3)]=uv21*0.3

# %%
sns.jointplot(x="crime_rate",y="price",data=df2)

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    3.613524   41.136779    0.554695    6.284634   68.574901
# std      9.182176    8.601545    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006320   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.082045   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.256510   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    3.677082   48.100000    0.624000    6.623500   94.075000
# max     50.000000   88.976200   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
df2.n_hos_beds=df2.n_hos_beds.fillna(df2.n_hos_beds.mean())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   506 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    506 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %%
sns.jointplot(x="crime_rate",y="price",data=df2)

# %%
df2.crime_rate=np.log(1+df2.crime_rate)

# %%
sns.jointplot(x="crime_rate",y="price",data=df2)

# %%
df2['avg_dist']=(df2.dist1+df2.dist2+df2.dist3+df2.dist4)/4

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist1       dist2       dist3       dist4    teachers   poor_prop  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.971996    3.628775    3.960672    3.618972   21.544466   12.653063
# ...

# %%
del df2['dist1']

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist2       dist3       dist4    teachers   poor_prop  n_hos_beds  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.628775    3.960672    3.618972   21.544466   12.653063    7.899767
# ...

# %%
del df2['dist2']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-e041521d65a3> in <module>
# ----> 1 del df2[dist2]
#
# NameError: name 'dist2' is not defined

# %%
del df2['dist3']

# %%
del df2['dist4']

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist3    teachers   poor_prop  n_hos_beds  n_hot_rooms  \
# count  506.000000  506.000000  506.000000  506.000000   506.000000
# mean     3.960672   21.544466   12.653063    7.899767    12.864050
# ...

# %%
del df2['bus_ter']

# %%
df2.describe()
# Out:
#             price  crime_rate  resid_area    air_qual    room_num         age  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.528854    0.813418   41.136779    0.554695    6.284634   68.574901
# std      9.182176    1.022731    6.860353    0.115878    0.702617   28.148861
# min      5.000000    0.006300   30.460000    0.385000    3.561000    2.900000
# 25%     17.025000    0.078853   35.190000    0.449000    5.885500   45.025000
# 50%     21.200000    0.228336   39.690000    0.538000    6.208500   77.500000
# 75%     25.000000    1.542674   48.100000    0.624000    6.623500   94.075000
# max     50.000000    4.499545   57.740000    0.871000    8.780000  100.000000
#
#             dist3    teachers   poor_prop  n_hos_beds  n_hot_rooms  \
# count  506.000000  506.000000  506.000000  506.000000   506.000000
# mean     3.960672   21.544466   12.653063    7.899767    12.864050
# ...

# %%
df2.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist3  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.18      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   5.12      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.01      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.16      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.37      21.3
#
#    poor_prop airport  n_hos_beds  n_hot_rooms waterbody  rainfall     parks  \
# 0       4.98     YES       5.480     11.19200     River        23  0.049347
# 1       9.14      NO       7.332     12.17280      Lake        42  0.046146
# 2       4.03      NO       7.394     46.19856      None        38  0.045764
# 3       2.94     YES       9.268     11.26720      Lake        45  0.047151
# 4       5.33      NO       8.824     11.28960      Lake        55  0.039474
#
#    avg_dist
# 0    4.0875
# 1    4.9675
# ...

# %%
df2=pd.get_dummies(df2)

# %%
df2.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist3  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.18      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   5.12      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.01      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.16      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.37      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_NO  airport_YES  waterbody_Lake  waterbody_Lake and River  \
# ...

# %%
del df2['airport_NO']

# %%
del df2['waterbody_None']

# %%
df2.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist3  teachers  \
# 0   24.0    0.006300       32.31     0.538     6.575  65.2   4.18      24.7
# 1   21.6    0.026944       37.07     0.469     6.421  78.9   5.12      22.2
# 2   34.7    0.026924       37.07     0.469     7.185  61.1   5.01      22.2
# 3   33.4    0.031857       32.18     0.458     6.998  45.8   6.16      21.3
# 4   36.2    0.066770       32.18     0.458     7.147  54.2   6.37      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
df2.corr()
# Out:
#                              price  crime_rate  resid_area  air_qual  \
# price                     1.000000   -0.466527   -0.484754 -0.429300
# crime_rate               -0.466527    1.000000    0.660283  0.707587
# resid_area               -0.484754    0.660283    1.000000  0.763651
# air_qual                 -0.429300    0.707587    0.763651  1.000000
# room_num                  0.696304   -0.288784   -0.391676 -0.302188
# age                      -0.377999    0.559591    0.644779  0.731470
# dist3                     0.246650   -0.587988   -0.707566 -0.769157
# teachers                  0.505655   -0.390052   -0.383248 -0.188933
# poor_prop                -0.740836    0.608970    0.603800  0.590879
# n_hos_beds                0.108880   -0.004089    0.005799 -0.049553
# n_hot_rooms               0.017007    0.056570   -0.003761  0.007238
# rainfall                 -0.047200    0.082151    0.055845  0.091956
# parks                    -0.391574    0.638951    0.707635  0.915544
# ...

# %%
import statsmodels.api as sn

# %%
X=sn.add_constant(df2['room_num'])

# %%
lm=sn.OLS(df2['price'],X).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.485
# Model:                            OLS   Adj. R-squared:                  0.484
# Method:                 Least Squares   F-statistic:                     474.3
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):           1.31e-74
# Time:                        16:58:12   Log-Likelihood:                -1671.6
# No. Observations:                 506   AIC:                             3347.
# Df Residuals:                     504   BIC:                             3356.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -34.6592      2.642    -13.118      0.000     -39.850     -29.468
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df2['price']

# %%
X = df2[['room_num']]

# %%
lm2=LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_, lm2.coef_)
# Out:
# -34.65924312309721 [9.09966966]

# %%
lm2.predict(X)
# Out:
# array([25.17108491, 23.76973578, 30.72188341, 29.02024518, 30.37609596,
#        23.85163281, 20.04797089, 21.50391804, 16.58099675, 19.97517353,
#        23.36935032, 20.02067188, 18.92871152, 19.4746917 , 20.81234314,
#        18.42822969, 19.34729633, 19.84777816, 14.98855456, 17.45456504,
#        16.0259169 , 19.62028642, 21.23092795, 18.23713663, 19.24719996,
#        16.28980732, 18.23713663, 20.36645933, 24.44311134, 26.07195221,
#        17.32716966, 20.59395107, 19.48379137, 17.21797363, 20.81234314,
#        19.32909699, 18.49192738, 18.57382441, 19.62938609, 25.3530783 ,
#        29.25683659, 26.9455205 , 21.47661903, 21.85880515, 20.56665206,
#        17.0450799 , 17.99144555, 20.21176495, 14.46987339, 16.31710633,
#        19.60208708, 20.98523687, 24.58870605, 19.92057552, 18.91961185,
#        31.30426226, 23.42394834, 27.3641053 , 21.25822696, 19.27449897,
#        17.58196041, 19.62938609, 24.08822422, 26.87272314, 29.98481016,
# ...

# %%
sns.jointplot(x=df2['room_num'],y=df2['price'],data=df2, kind='reg')

# %%
X_multi=df2.drop('price',axis=1)

# %%
X_multi.head()
# Out:
#    crime_rate  resid_area  air_qual  room_num   age  dist3  teachers  \
# 0    0.006300       32.31     0.538     6.575  65.2   4.18      24.7
# 1    0.026944       37.07     0.469     6.421  78.9   5.12      22.2
# 2    0.026924       37.07     0.469     7.185  61.1   5.01      22.2
# 3    0.031857       32.18     0.458     6.998  45.8   6.16      21.3
# 4    0.066770       32.18     0.458     7.147  54.2   6.37      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
y_multi=df2['price']

# %%
y_multi.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: price, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons.head()
# Out:
#    const  crime_rate  resid_area  air_qual  room_num   age  dist3  teachers  \
# 0    1.0    0.006300       32.31     0.538     6.575  65.2   4.18      24.7
# 1    1.0    0.026944       37.07     0.469     6.421  78.9   5.12      22.2
# 2    1.0    0.026924       37.07     0.469     7.185  61.1   5.01      22.2
# 3    1.0    0.031857       32.18     0.458     6.998  45.8   6.16      21.3
# 4    1.0    0.066770       32.18     0.458     7.147  54.2   6.37      21.3
#
#    poor_prop  n_hos_beds  n_hot_rooms  rainfall     parks  avg_dist  \
# 0       4.98       5.480     11.19200        23  0.049347    4.0875
# 1       9.14       7.332     12.17280        42  0.046146    4.9675
# 2       4.03       7.394     46.19856        38  0.045764    4.9675
# 3       2.94       9.268     11.26720        45  0.047151    6.0650
# 4       5.33       8.824     11.28960        55  0.039474    6.0625
#
#    airport_YES  waterbody_Lake  waterbody_Lake and River  waterbody_River
# ...

# %%
lm_multi=sn.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.722
# Model:                            OLS   Adj. R-squared:                  0.712
# Method:                 Least Squares   F-statistic:                     74.47
# Date:                Wed, 24 Aug 2022   Prob (F-statistic):          1.54e-123
# Time:                        17:38:39   Log-Likelihood:                -1515.7
# No. Observations:                 506   AIC:                             3067.
# Df Residuals:                     488   BIC:                             3144.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
lm3=LinearRegression()

# %%
lm3.fit(X_multi_cons,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# -6.72318955985256 [ 0.00000000e+00  1.68635265e-02 -4.25615978e-02 -2.06568985e+01
#   4.00090357e+00 -5.47407551e-03 -1.44221077e+00  1.01462376e+00
#  -5.77230347e-01  3.40338888e-01  8.90649895e-02  1.53195305e-02
#   5.62506417e+01  2.31350036e-01  1.10542184e+00  2.44779486e-01
#  -6.99108327e-01 -2.74096842e-01]

# %%
lm3.predict(X_multi_cons)
# Out:
# array([30.6625377 , 25.34664886, 34.33314601, 31.47762049, 28.81218326,
#        27.08117505, 23.43166559, 18.86796582, 11.24691753, 20.19237426,
#        18.19346523, 21.07377969, 20.79758059, 20.48275663, 20.06270955,
#        20.97684965, 20.68673703, 16.60686008, 18.08315796, 17.91954846,
#        12.38540681, 18.77830508, 15.831449  , 14.52619053, 16.36181308,
#        15.08217978, 16.54646387, 16.48458446, 19.97855779, 21.22028099,
#        12.2942805 , 19.19413859,  9.24707678, 15.57977965, 16.02970464,
#        24.67737266, 21.60337696, 23.31779362, 23.03390388, 29.62970813,
#        32.21188555, 28.17363703, 26.00069789, 25.9353908 , 23.18095638,
#        21.49454425, 21.8218842 , 18.06494554,  7.52610765, 15.96977268,
#        20.66415839, 24.12414302, 28.24093238, 23.72294178, 16.44975369,
#        29.52284678, 24.23094245, 31.66473185, 20.39910062, 19.88102111,
#        15.20857672, 15.51085987, 22.84865571, 21.18055383, 23.91368301,
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,y_train,y_test = train_test_split(X_multi,y_multi, test_size=0.2)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (404, 17) (102, 17) (404,) (102,)

# %%
lm_a=LinearRegression()

# %%
lm_a.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a=lm_a.predict(X_test)

# %%
y_train_a=lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_test_a)
# Out:
# 0.6668531232947981

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.7259393386943209

# %% [markdown]
# # LASSO AND RIDGE REGRESION

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.StandardScaler().fit(X_train)

# %%
X_train_s=scaler.transform(X_train)

# %%
X_test_s=scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
lm_r = Ridge(alpha=0.5)
lm_r.fit(X_train_s, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
r2_score(y_test, lm_r.predict(X_test_s))
# Out:
# -114.10539489331107

# %%
from sklearn.model_selection import validation_curve

# %%
param_range=np.logspace(-2,8,100)

# %%
param_range
# Out:
# array([1.00000000e-02, 1.26185688e-02, 1.59228279e-02, 2.00923300e-02,
#        2.53536449e-02, 3.19926714e-02, 4.03701726e-02, 5.09413801e-02,
#        6.42807312e-02, 8.11130831e-02, 1.02353102e-01, 1.29154967e-01,
#        1.62975083e-01, 2.05651231e-01, 2.59502421e-01, 3.27454916e-01,
#        4.13201240e-01, 5.21400829e-01, 6.57933225e-01, 8.30217568e-01,
#        1.04761575e+00, 1.32194115e+00, 1.66810054e+00, 2.10490414e+00,
#        2.65608778e+00, 3.35160265e+00, 4.22924287e+00, 5.33669923e+00,
#        6.73415066e+00, 8.49753436e+00, 1.07226722e+01, 1.35304777e+01,
#        1.70735265e+01, 2.15443469e+01, 2.71858824e+01, 3.43046929e+01,
#        4.32876128e+01, 5.46227722e+01, 6.89261210e+01, 8.69749003e+01,
#        1.09749877e+02, 1.38488637e+02, 1.74752840e+02, 2.20513074e+02,
#        2.78255940e+02, 3.51119173e+02, 4.43062146e+02, 5.59081018e+02,
#        7.05480231e+02, 8.90215085e+02, 1.12332403e+03, 1.41747416e+03,
# ...

# %%
train_scores, test_scores = validation_curve(Ridge(),X_train_s,y_train,"alpha", param_range,scoring='r2')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass param_name=alpha, param_range=[1.00000000e-02 1.26185688e-02 1.59228279e-02 2.00923300e-02
#  2.53536449e-02 3.19926714e-02 4.03701726e-02 5.09413801e-02
#  6.42807312e-02 8.11130831e-02 1.02353102e-01 1.29154967e-01
#  1.62975083e-01 2.05651231e-01 2.59502421e-01 3.27454916e-01
#  4.13201240e-01 5.21400829e-01 6.57933225e-01 8.30217568e-01
#  1.04761575e+00 1.32194115e+00 1.66810054e+00 2.10490414e+00
#  2.65608778e+00 3.35160265e+00 4.22924287e+00 5.33669923e+00
#  6.73415066e+00 8.49753436e+00 1.07226722e+01 1.35304777e+01
#  1.70735265e+01 2.15443469e+01 2.71858824e+01 3.43046929e+01
#  4.32876128e+01 5.46227722e+01 6.89261210e+01 8.69749003e+01
#  1.09749877e+02 1.38488637e+02 1.74752840e+02 2.20513074e+02
#  2.78255940e+02 3.51119173e+02 4.43062146e+02 5.59081018e+02
#  7.05480231e+02 8.90215085e+02 1.12332403e+03 1.41747416e+03
# ...

# %%
print(train_scores)
print(test_scores)
# Out:
# [[7.33413374e-01 7.33531376e-01 7.21887480e-01 7.28627833e-01
#   7.28699002e-01]
#  [7.33413334e-01 7.33531369e-01 7.21887432e-01 7.28627801e-01
#   7.28698910e-01]
#  [7.33413273e-01 7.33531359e-01 7.21887358e-01 7.28627750e-01
#   7.28698767e-01]
#  [7.33413179e-01 7.33531342e-01 7.21887244e-01 7.28627672e-01
#   7.28698547e-01]
#  [7.33413035e-01 7.33531317e-01 7.21887070e-01 7.28627553e-01
#   7.28698212e-01]
#  [7.33412817e-01 7.33531278e-01 7.21886806e-01 7.28627373e-01
#   7.28697709e-01]
#  [7.33412492e-01 7.33531220e-01 7.21886412e-01 7.28627103e-01
#   7.28696960e-01]
#  [7.33412013e-01 7.33531133e-01 7.21885832e-01 7.28626705e-01
#   7.28695864e-01]
#  [7.33411321e-01 7.33531007e-01 7.21884992e-01 7.28626128e-01
#   7.28694290e-01]
#  [7.33410339e-01 7.33530824e-01 7.21883799e-01 7.28625306e-01
#   7.28692079e-01]
#  [7.33408980e-01 7.33530566e-01 7.21882147e-01 7.28624163e-01
#   7.28689050e-01]
#  [7.33407146e-01 7.33530207e-01 7.21879918e-01 7.28622614e-01
# ...

# %%
test_mean=np.mean(test_scores,axis=1)

# %%
train_mean=np.mean(train_scores,axis=1)

# %%
train_mean
# Out:
# array([7.29231813e-01, 7.29231769e-01, 7.29231701e-01, 7.29231597e-01,
#        7.29231437e-01, 7.29231197e-01, 7.29230837e-01, 7.29230309e-01,
#        7.29229547e-01, 7.29228469e-01, 7.29226981e-01, 7.29224980e-01,
#        7.29222369e-01, 7.29219063e-01, 7.29215011e-01, 7.29210186e-01,
#        7.29204585e-01, 7.29198189e-01, 7.29190913e-01, 7.29182523e-01,
#        7.29172539e-01, 7.29160095e-01, 7.29143769e-01, 7.29121332e-01,
#        7.29089427e-01, 7.29043118e-01, 7.28975311e-01, 7.28876015e-01,
#        7.28731436e-01, 7.28522861e-01, 7.28225262e-01, 7.27805423e-01,
#        7.27219250e-01, 7.26407775e-01, 7.25291280e-01, 7.23761147e-01,
#        7.21669392e-01, 7.18816536e-01, 7.14939298e-01, 7.09700776e-01,
#        7.02687146e-01, 6.93416321e-01, 6.81364457e-01, 6.66014173e-01,
#        6.46922686e-01, 6.23799170e-01, 5.96572216e-01, 5.65425976e-01,
#        5.30791689e-01, 4.93297958e-01, 4.53699561e-01, 4.12810396e-01,
# ...

# %%
max(test_mean)
# Out:
# 0.6869427554521024

# %%
sns.jointplot(x=np.log(param_range),y=test_mean)

# %%
np.where(test_mean==max(test_mean))
# Out:
# (array([34], dtype=int64),)

# %%
param_range[34]
# Out:
# 27.1858824273294

# %%
lm_r_best=Ridge(alpha=param_range[34])

# %%
lm_r_best.fit(X_train_s,y_train)
# Out:
# Ridge(alpha=27.1858824273294)

# %% [raw]
# r2_score(y_test, lm_r_best.predict(X_test_s))

# %%
r2_score(y_train,lm_r_best.predict(X_train_s))
# Out:
# 0.7232513578415403

# %%
from sklearn.linear_model import Lasso

# %%
lm_l=Lasso(alpha=0.4)
